# %%
import numpy as np
import pandas as pd
import re, os

all_files = os.listdir()
    bcourse = '.*_Grades-ENGIN_7.csv'
iclicker = 'iClicker_GradesExport_Canvas_.*.csv'

for i in all_files:
	if re.match(bcourse, i):
		bcourse = i
	if re.match(iclicker, i):
		iclicker = i

ic = pd.read_csv(iclicker)
bc = pd.read_csv(bcourse)
new_bc = bc.copy()

def poll_name():
	search_type = [i for i in ic.columns if re.match('Class \d+ - Poll', i)][0]
	return [i for i in bc.columns if re.match(search_type+' .*', i)][0]

for i in bc.iterrows():
	stu = ic[ic['SIS User ID'] == i[1]['SIS User ID']]
	if (stu['Student'].values.size > 0) and (stu['Current Score'].values.size > 0):
		# if stu['Student'].values[0]!=i[1]['Student']:
		# 	print(stu['Student'].values[0], i[1]['Student'])
		poll_num = list(i[1].index).index([j for j in i[1].index if poll_name() in j][0])
		max_score = max(float(stu['Current Score'].values[0]), i[1][poll_num])
		print(i[1]['Student'], max_score)
		idx = new_bc[new_bc['SIS User ID'] == i[1]['SIS User ID']].index
		new_bc.at[idx.values[0], poll_name()] = str(max_score)
		print('Previous', i[1][poll_num])
		print('updated', new_bc[new_bc['SIS User ID'] == i[1]['SIS User ID']][poll_name()])
u = list(new_bc.columns[:5])+[poll_name()]
new_bc[u].to_csv('updated_'+bcourse, encoding='utf-8-sig', index=False)
# Out:
# Andrade, Luke 2.0
# Previous 2.0
# updated 1    2.0
# Name: Class 15 - Poll (8909750), dtype: object
# Bautista, Carlos 2.4
# Previous 2.4
# updated 2    2.4
# Name: Class 15 - Poll (8909750), dtype: object
# Fonseca Gutierrez, Gael 2.0
# Previous nan
# updated 3    2.0
# Name: Class 15 - Poll (8909750), dtype: object
# Grochowski, Ava 0.0
# Previous nan
# updated 4    0.0
# Name: Class 15 - Poll (8909750), dtype: object
# Hoang, Colin 2.4
# Previous 2.4
# updated 5    2.4
# Name: Class 15 - Poll (8909750), dtype: object
# Lim, Shu-Han 2.4
# Previous nan
# updated 6    2.4
# Name: Class 15 - Poll (8909750), dtype: object
# Mccaffery, Sabrina 2.4
# Previous 2.4
# updated 7    2.4
# Name: Class 15 - Poll (8909750), dtype: object
# Mejia, Jacob 2.0
# Previous nan
# updated 8    2.0
# Name: Class 15 - Poll (8909750), dtype: object
# Montero, Leilani 2.4
# Previous 2.4
# updated 9    2.4
# Name: Class 15 - Poll (8909750), dtype: object
# Pon, Sienna 2.8
# Previous 2.8
# updated 10    2.8
# Name: Class 15 - Poll (8909750), dtype: object
# Romero Reyes, Gary 2.0
# Previous 2.0
# updated 11    2.0
# Name: Class 15 - Poll (8909750), dtype: object
# Schmidtke, Eric 2.4
# Previous 2.4
# updated 12    2.4
# Name: Class 15 - Poll (8909750), dtype: object
# Wang, Angela 1.0
# Previous nan
# updated 13    1.0
# Name: Class 15 - Poll (8909750), dtype: object
# Wang, Samuel 2.4
# Previous 2.4
# updated 14    2.4
# Name: Class 15 - Poll (8909750), dtype: object
# Yu, Changyuan 2.8
# Previous 2.8
# updated 15    2.8
# Name: Class 15 - Poll (8909750), dtype: object
# /tmp/ipykernel_73/773544466.py:29: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   max_score = max(float(stu['Current Score'].values[0]), i[1][poll_num])
# /tmp/ipykernel_73/773544466.py:32: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2.0' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   new_bc.at[idx.values[0], poll_name()] = str(max_score)
# /tmp/ipykernel_73/773544466.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print('Previous', i[1][poll_num])
# /tmp/ipykernel_73/773544466.py:29: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   max_score = max(float(stu['Current Score'].values[0]), i[1][poll_num])
